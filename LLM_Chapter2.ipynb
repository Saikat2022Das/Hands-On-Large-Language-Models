# %%
# !pip install --upgrade transformers==4.41.2 sentence-transformers==3.0.1 gensim==4.3.2 scikit-learn==1.5.0 accelerate==0.31.0 peft==0.11.1 scipy==1.10.1 numpy==1.26.4
# Out:
# Collecting transformers==4.41.2
#   Downloading transformers-4.41.2-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 3.0 MB/s eta 0:00:00
# Collecting sentence-transformers==3.0.1
#   Downloading sentence_transformers-3.0.1-py3-none-any.whl.metadata (10 kB)
# Collecting gensim==4.3.2
#   Downloading gensim-4.3.2.tar.gz (23.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 30.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting scikit-learn==1.5.0
#   Downloading scikit_learn-1.5.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting accelerate==0.31.0
#   Downloading accelerate-0.31.0-py3-none-any.whl.metadata (19 kB)
# Collecting peft==0.11.1
#   Downloading peft-0.11.1-py3-none-any.whl.metadata (13 kB)
# ERROR: Ignored the following yanked versions: 1.11.0, 1.14.0rc1
# ERROR: Ignored the following versions that require a different python version: 1.10.0 Requires-Python <3.12,>=3.8; 1.10.0rc1 Requires-Python <3.12,>=3.8; 1.10.0rc2 Requires-Python <3.12,>=3.8; 1.10.1 Requires-Python <3.12,>=3.8; 1.6.2 Requires-Python >=3.7,<3.10; 1.6.3 Requires-Python >=3.7,<3.10; 1.7.0 Requires-Python >=3.7,<3.10; 1.7.1 Requires-Python >=3.7,<3.10; 1.7.2 Requires-Python >=3.7,<3.11; 1.7.3 Requires-Python >=3.7,<3.11; 1.8.0 Requires-Python >=3.8,<3.11; 1.8.0rc1 Requires-Python >=3.8,<3.11; 1.8.0rc2 Requires-Python >=3.8,<3.11; 1.8.0rc3 Requires-Python >=3.8,<3.11; 1.8.0rc4 Requires-Python >=3.8,<3.11; 1.8.1 Requires-Python >=3.8,<3.11; 1.9.0 Requires-Python >=3.8,<3.12; 1.9.0rc1 Requires-Python >=3.8,<3.12; 1.9.0rc2 Requires-Python >=3.8,<3.12; 1.9.0rc3 Requires-Python >=3.8,<3.12; 1.9.1 Requires-Python >=3.8,<3.12
# ERROR: Could not find a version that satisfies the requirement scipy==1.10.1 (from versions: 0.8.0, 0.9.0, 0.10.0, 0.10.1, 0.11.0, 0.12.0, 0.12.1, 0.13.0, 0.13.1, 0.13.2, 0.13.3, 0.14.0, 0.14.1, 0.15.0, 0.15.1, 0.16.0, 0.16.1, 0.17.0, 0.17.1, 0.18.0, 0.18.1, 0.19.0, 0.19.1, 1.0.0, 1.0.1, 1.1.0, 1.2.0, 1.2.1, 1.2.2, 1.2.3, 1.3.0, 1.3.1, 1.3.2, 1.3.3, 1.4.0, 1.4.1, 1.5.0, 1.5.1, 1.5.2, 1.5.3, 1.5.4, 1.6.0, 1.6.1, 1.9.2, 1.9.3, 1.11.0rc1, 1.11.0rc2, 1.11.1, 1.11.2, 1.11.3, 1.11.4, 1.12.0rc1, 1.12.0rc2, 1.12.0, 1.13.0rc1, 1.13.0, 1.13.1, 1.14.0rc2, 1.14.0, 1.14.1, 1.15.0rc1, 1.15.0rc2, 1.15.0, 1.15.1, 1.15.2, 1.15.3, 1.16.0rc1, 1.16.0rc2, 1.16.0, 1.16.1, 1.16.2, 1.16.3, 1.17.0rc1)
# ERROR: No matching distribution found for scipy==1.10.1

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

# Load model and tokenizer
model = AutoModelForCausalLM.from_pretrained(
    "microsoft/Phi-3-mini-4k-instruct",
    device_map="cuda",
    torch_dtype="auto",
    trust_remote_code=False,
)
tokenizer = AutoTokenizer.from_pretrained("microsoft/Phi-3-mini-4k-instruct")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# config.json:   0%|          | 0.00/967 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.67G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/181 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/306 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/599 [00:00<?, ?B/s]

# %%
prompt = "Write an email apologizing to Sarah for the tragic gardening mishap. Explain how it happened.<|assistant|>"

# %%
# Tokenize the input prompt
input_ids = tokenizer(prompt, return_tensors="pt").input_ids.to("cuda")

# %%
# Generate the text
generation_output = model.generate(
  input_ids=input_ids,
  max_new_tokens=20
)

# %%
print(tokenizer.decode(generation_output[0]))
# Out:
# Write an email apologizing to Sarah for the tragic gardening mishap. Explain how it happened.<|assistant|> Subject: Heartfelt Apologies for the Gardening Mishap
#
#
# Dear

# %%
print(input_ids)
# Out:
# tensor([[14350,   385,  4876, 27746,  5281,   304, 19235,   363,   278, 25305,
#            293, 16423,   292,   286,   728,   481, 29889, 12027,  7420,   920,
#            372,  9559, 29889, 32001]], device='cuda:0')

# %%
for id in input_ids:
  print(tokenizer.decode(id))
# Out:
# Write an email apologizing to Sarah for the tragic gardening mishap. Explain how it happened.<|assistant|>

# %%
print(generation_output)
# Out:
# tensor([[14350,   385,  4876, 27746,  5281,   304, 19235,   363,   278, 25305,
#            293, 16423,   292,   286,   728,   481, 29889, 12027,  7420,   920,
#            372,  9559, 29889, 32001,  3323,   622, 29901, 17778, 29888,  2152,
#           6225, 11763,   363,   278, 19906,   292,   341,   728,   481,    13,
#             13,    13, 29928,   799]], device='cuda:0')

# %%
print(tokenizer.decode(14350))
print(tokenizer.decode(728))
# Out:
# Write
# ish

# %%
### Comparing Trained LLM Tokenizers

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

# %%
colors_list = [
    '102;194;165', '252;141;98', '141;160;203',
    '231;138;195', '166;216;84', '255;217;47'
]

# %%
def show_tokens(sentence, tokenizer_name):
    tokenizer = AutoTokenizer.from_pretrained(tokenizer_name)
    token_ids = tokenizer(sentence).input_ids
    for idx, t in enumerate(token_ids):
        print(
            f'\x1b[0;30;48;2;{colors_list[idx % len(colors_list)]}m' +
            tokenizer.decode(t) +
            '\x1b[0m',
            end=' '
        )

# %%
text = """
English and CAPITALIZATION
🎵 鸟
show_tokens False None elif == >= else: two tabs:"    " Three tabs: "       "
12.0*50=600
"""

# %%
show_tokens(text, "microsoft/Phi-3-mini-4k-instruct")
# Out:
#
#  English and C AP IT AL IZ ATION
#  � � � �  � � �
#  show _ to kens False None elif == >= else : two tabs :"    " Three tabs : "       "
#  1 2 . 0 * 5 0 = 6 0 0

# %%
show_tokens(text, "bert-base-cased")
# Out:
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# [CLS] English and CA ##PI ##TA ##L ##I ##Z ##AT ##ION [UNK] [UNK] show _ token ##s F ##als ##e None el ##if = = > = else : two ta ##bs : " " Three ta ##bs : " " 12 . 0 * 50 = 600 [SEP]

# %%
show_tokens(text, "bert-base-uncased")
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# [CLS] english and capital ##ization [UNK] [UNK] show _ token ##s false none eli ##f = = > = else : two tab ##s : " " three tab ##s : " " 12 . 0 * 50 = 600 [SEP]

# %%
show_tokens(text, "gpt2")
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
#  English  and  CAP ITAL IZ ATION
#  � � �  � � �
#  show _ t ok ens  False  None  el if  ==  >=  else :  two  tabs :"        "  Three  tabs :  "              "
#  12 . 0 * 50 = 600

# %% [markdown]
# Contextualized Word Embeddings From a Language Model (Like BERT)

# %%
from transformers import AutoModel, AutoTokenizer

# %%
# Load a Tokenizer
tokenizer = AutoTokenizer.from_pretrained("microsoft/deberta-base")

# Load a Language Model
model = AutoModel.from_pretrained("microsoft/deberta-v3-xsmall")

# Tokenize the sentence
tokens = tokenizer("Hello World", return_tensors = "pt")

output = model(**tokens)[0]
# Out:
# tokenizer_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/474 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/578 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/241M [00:00<?, ?B/s]

# %%
output[0].shape
# Out:
# torch.Size([4, 384])

# %%
for token in tokens["input_ids"][0]:
  print(tokenizer.decode(token))
# Out:
# [CLS]
# Hello
#  World
# [SEP]

# %%
print(tokens)
# Out:
# {'input_ids': tensor([[    1, 31414,   623,     2]]), 'token_type_ids': tensor([[0, 0, 0, 0]]), 'attention_mask': tensor([[1, 1, 1, 1]])}

# %%
output
# Out:
# tensor([[[-3.2520,  0.1818, -0.1254,  ..., -0.0502, -0.2334,  0.8897],
#          [-0.4673,  0.1730, -0.0206,  ..., -0.5289,  0.7303,  2.1177],
#          [-0.4950,  0.0564,  0.2842,  ...,  1.0543, -0.1747,  1.3793],
#          [-2.9601,  0.2129, -0.1138,  ...,  0.1518, -0.2094,  1.0494]]],
#        grad_fn=<NativeLayerNormBackward0>)

# %%
# e.g., embeddings for the first token
token_embeddings = output[0]  # Shape: (1, 4, 384)
# Access shape to get token embeddings for the specific tokens
for i in range(token_embeddings.shape[1]):
    embedding = token_embeddings[0, i]  # shape will be (384,)
    print(f"Embedding for token {i}: {embedding.shape}")  # (384,)
# Out:
# Embedding for token 0: torch.Size([])
# Embedding for token 1: torch.Size([])
# Embedding for token 2: torch.Size([])
# Embedding for token 3: torch.Size([])
# Embedding for token 4: torch.Size([])
# Embedding for token 5: torch.Size([])
# Embedding for token 6: torch.Size([])
# Embedding for token 7: torch.Size([])
# Embedding for token 8: torch.Size([])
# Embedding for token 9: torch.Size([])
# Embedding for token 10: torch.Size([])
# Embedding for token 11: torch.Size([])
# Embedding for token 12: torch.Size([])
# Embedding for token 13: torch.Size([])
# Embedding for token 14: torch.Size([])
# Embedding for token 15: torch.Size([])
# Embedding for token 16: torch.Size([])
# Embedding for token 17: torch.Size([])
# Embedding for token 18: torch.Size([])
# Embedding for token 19: torch.Size([])
# Embedding for token 20: torch.Size([])
# Embedding for token 21: torch.Size([])
# Embedding for token 22: torch.Size([])
# Embedding for token 23: torch.Size([])
# Embedding for token 24: torch.Size([])
# Embedding for token 25: torch.Size([])
# Embedding for token 26: torch.Size([])
# Embedding for token 27: torch.Size([])
# Embedding for token 28: torch.Size([])
# Embedding for token 29: torch.Size([])
# Embedding for token 30: torch.Size([])
# Embedding for token 31: torch.Size([])
# Embedding for token 32: torch.Size([])
# Embedding for token 33: torch.Size([])
# Embedding for token 34: torch.Size([])
# Embedding for token 35: torch.Size([])
# Embedding for token 36: torch.Size([])
# Embedding for token 37: torch.Size([])
# Embedding for token 38: torch.Size([])
# Embedding for token 39: torch.Size([])
# Embedding for token 40: torch.Size([])
# Embedding for token 41: torch.Size([])
# Embedding for token 42: torch.Size([])
# Embedding for token 43: torch.Size([])
# Embedding for token 44: torch.Size([])
# Embedding for token 45: torch.Size([])
# Embedding for token 46: torch.Size([])
# Embedding for token 47: torch.Size([])
# Embedding for token 48: torch.Size([])
# Embedding for token 49: torch.Size([])
# Embedding for token 50: torch.Size([])
# Embedding for token 51: torch.Size([])
# Embedding for token 52: torch.Size([])
# Embedding for token 53: torch.Size([])
# Embedding for token 54: torch.Size([])
# Embedding for token 55: torch.Size([])
# Embedding for token 56: torch.Size([])
# Embedding for token 57: torch.Size([])
# Embedding for token 58: torch.Size([])
# Embedding for token 59: torch.Size([])
# Embedding for token 60: torch.Size([])
# Embedding for token 61: torch.Size([])
# Embedding for token 62: torch.Size([])
# Embedding for token 63: torch.Size([])
# Embedding for token 64: torch.Size([])
# Embedding for token 65: torch.Size([])
# Embedding for token 66: torch.Size([])
# Embedding for token 67: torch.Size([])
# Embedding for token 68: torch.Size([])
# Embedding for token 69: torch.Size([])
# Embedding for token 70: torch.Size([])
# Embedding for token 71: torch.Size([])
# Embedding for token 72: torch.Size([])
# Embedding for token 73: torch.Size([])
# Embedding for token 74: torch.Size([])
# Embedding for token 75: torch.Size([])
# Embedding for token 76: torch.Size([])
# Embedding for token 77: torch.Size([])
# Embedding for token 78: torch.Size([])
# Embedding for token 79: torch.Size([])
# Embedding for token 80: torch.Size([])
# Embedding for token 81: torch.Size([])
# Embedding for token 82: torch.Size([])
# Embedding for token 83: torch.Size([])
# Embedding for token 84: torch.Size([])
# Embedding for token 85: torch.Size([])
# Embedding for token 86: torch.Size([])
# Embedding for token 87: torch.Size([])
# Embedding for token 88: torch.Size([])
# Embedding for token 89: torch.Size([])
# Embedding for token 90: torch.Size([])
# Embedding for token 91: torch.Size([])
# Embedding for token 92: torch.Size([])
# Embedding for token 93: torch.Size([])
# Embedding for token 94: torch.Size([])
# Embedding for token 95: torch.Size([])
# Embedding for token 96: torch.Size([])
# Embedding for token 97: torch.Size([])
# Embedding for token 98: torch.Size([])
# Embedding for token 99: torch.Size([])
# Embedding for token 100: torch.Size([])
# Embedding for token 101: torch.Size([])
# Embedding for token 102: torch.Size([])
# Embedding for token 103: torch.Size([])
# Embedding for token 104: torch.Size([])
# Embedding for token 105: torch.Size([])
# Embedding for token 106: torch.Size([])
# Embedding for token 107: torch.Size([])
# Embedding for token 108: torch.Size([])
# Embedding for token 109: torch.Size([])
# Embedding for token 110: torch.Size([])
# Embedding for token 111: torch.Size([])
# Embedding for token 112: torch.Size([])
# Embedding for token 113: torch.Size([])
# Embedding for token 114: torch.Size([])
# Embedding for token 115: torch.Size([])
# Embedding for token 116: torch.Size([])
# Embedding for token 117: torch.Size([])
# Embedding for token 118: torch.Size([])
# Embedding for token 119: torch.Size([])
# Embedding for token 120: torch.Size([])
# Embedding for token 121: torch.Size([])
# Embedding for token 122: torch.Size([])
# Embedding for token 123: torch.Size([])
# Embedding for token 124: torch.Size([])
# Embedding for token 125: torch.Size([])
# Embedding for token 126: torch.Size([])
# Embedding for token 127: torch.Size([])
# Embedding for token 128: torch.Size([])
# Embedding for token 129: torch.Size([])
# Embedding for token 130: torch.Size([])
# Embedding for token 131: torch.Size([])
# Embedding for token 132: torch.Size([])
# Embedding for token 133: torch.Size([])
# Embedding for token 134: torch.Size([])
# Embedding for token 135: torch.Size([])
# Embedding for token 136: torch.Size([])
# Embedding for token 137: torch.Size([])
# Embedding for token 138: torch.Size([])
# Embedding for token 139: torch.Size([])
# Embedding for token 140: torch.Size([])
# Embedding for token 141: torch.Size([])
# Embedding for token 142: torch.Size([])
# Embedding for token 143: torch.Size([])
# Embedding for token 144: torch.Size([])
# Embedding for token 145: torch.Size([])
# Embedding for token 146: torch.Size([])
# Embedding for token 147: torch.Size([])
# Embedding for token 148: torch.Size([])
# Embedding for token 149: torch.Size([])
# Embedding for token 150: torch.Size([])
# Embedding for token 151: torch.Size([])
# Embedding for token 152: torch.Size([])
# Embedding for token 153: torch.Size([])
# Embedding for token 154: torch.Size([])
# Embedding for token 155: torch.Size([])
# Embedding for token 156: torch.Size([])
# Embedding for token 157: torch.Size([])
# Embedding for token 158: torch.Size([])
# Embedding for token 159: torch.Size([])
# Embedding for token 160: torch.Size([])
# Embedding for token 161: torch.Size([])
# Embedding for token 162: torch.Size([])
# Embedding for token 163: torch.Size([])
# Embedding for token 164: torch.Size([])
# Embedding for token 165: torch.Size([])
# Embedding for token 166: torch.Size([])
# Embedding for token 167: torch.Size([])
# Embedding for token 168: torch.Size([])
# Embedding for token 169: torch.Size([])
# Embedding for token 170: torch.Size([])
# Embedding for token 171: torch.Size([])
# Embedding for token 172: torch.Size([])
# Embedding for token 173: torch.Size([])
# Embedding for token 174: torch.Size([])
# Embedding for token 175: torch.Size([])
# Embedding for token 176: torch.Size([])
# Embedding for token 177: torch.Size([])
# Embedding for token 178: torch.Size([])
# Embedding for token 179: torch.Size([])
# Embedding for token 180: torch.Size([])
# Embedding for token 181: torch.Size([])
# Embedding for token 182: torch.Size([])
# Embedding for token 183: torch.Size([])
# Embedding for token 184: torch.Size([])
# Embedding for token 185: torch.Size([])
# Embedding for token 186: torch.Size([])
# Embedding for token 187: torch.Size([])
# Embedding for token 188: torch.Size([])
# Embedding for token 189: torch.Size([])
# Embedding for token 190: torch.Size([])
# Embedding for token 191: torch.Size([])
# Embedding for token 192: torch.Size([])
# Embedding for token 193: torch.Size([])
# Embedding for token 194: torch.Size([])
# Embedding for token 195: torch.Size([])
# Embedding for token 196: torch.Size([])
# Embedding for token 197: torch.Size([])
# Embedding for token 198: torch.Size([])
# Embedding for token 199: torch.Size([])
# Embedding for token 200: torch.Size([])
# Embedding for token 201: torch.Size([])
# Embedding for token 202: torch.Size([])
# Embedding for token 203: torch.Size([])
# Embedding for token 204: torch.Size([])
# Embedding for token 205: torch.Size([])
# Embedding for token 206: torch.Size([])
# Embedding for token 207: torch.Size([])
# Embedding for token 208: torch.Size([])
# Embedding for token 209: torch.Size([])
# Embedding for token 210: torch.Size([])
# Embedding for token 211: torch.Size([])
# Embedding for token 212: torch.Size([])
# Embedding for token 213: torch.Size([])
# Embedding for token 214: torch.Size([])
# Embedding for token 215: torch.Size([])
# Embedding for token 216: torch.Size([])
# Embedding for token 217: torch.Size([])
# Embedding for token 218: torch.Size([])
# Embedding for token 219: torch.Size([])
# Embedding for token 220: torch.Size([])
# Embedding for token 221: torch.Size([])
# Embedding for token 222: torch.Size([])
# Embedding for token 223: torch.Size([])
# Embedding for token 224: torch.Size([])
# Embedding for token 225: torch.Size([])
# Embedding for token 226: torch.Size([])
# Embedding for token 227: torch.Size([])
# Embedding for token 228: torch.Size([])
# Embedding for token 229: torch.Size([])
# Embedding for token 230: torch.Size([])
# Embedding for token 231: torch.Size([])
# Embedding for token 232: torch.Size([])
# Embedding for token 233: torch.Size([])
# Embedding for token 234: torch.Size([])
# Embedding for token 235: torch.Size([])
# Embedding for token 236: torch.Size([])
# Embedding for token 237: torch.Size([])
# Embedding for token 238: torch.Size([])
# Embedding for token 239: torch.Size([])
# Embedding for token 240: torch.Size([])
# Embedding for token 241: torch.Size([])
# Embedding for token 242: torch.Size([])
# Embedding for token 243: torch.Size([])
# Embedding for token 244: torch.Size([])
# Embedding for token 245: torch.Size([])
# Embedding for token 246: torch.Size([])
# Embedding for token 247: torch.Size([])
# Embedding for token 248: torch.Size([])
# Embedding for token 249: torch.Size([])
# Embedding for token 250: torch.Size([])
# Embedding for token 251: torch.Size([])
# Embedding for token 252: torch.Size([])
# Embedding for token 253: torch.Size([])
# Embedding for token 254: torch.Size([])
# Embedding for token 255: torch.Size([])
# Embedding for token 256: torch.Size([])
# Embedding for token 257: torch.Size([])
# Embedding for token 258: torch.Size([])
# Embedding for token 259: torch.Size([])
# Embedding for token 260: torch.Size([])
# Embedding for token 261: torch.Size([])
# Embedding for token 262: torch.Size([])
# Embedding for token 263: torch.Size([])
# Embedding for token 264: torch.Size([])
# Embedding for token 265: torch.Size([])
# Embedding for token 266: torch.Size([])
# Embedding for token 267: torch.Size([])
# Embedding for token 268: torch.Size([])
# Embedding for token 269: torch.Size([])
# Embedding for token 270: torch.Size([])
# Embedding for token 271: torch.Size([])
# Embedding for token 272: torch.Size([])
# Embedding for token 273: torch.Size([])
# Embedding for token 274: torch.Size([])
# Embedding for token 275: torch.Size([])
# Embedding for token 276: torch.Size([])
# Embedding for token 277: torch.Size([])
# Embedding for token 278: torch.Size([])
# Embedding for token 279: torch.Size([])
# Embedding for token 280: torch.Size([])
# Embedding for token 281: torch.Size([])
# Embedding for token 282: torch.Size([])
# Embedding for token 283: torch.Size([])
# Embedding for token 284: torch.Size([])
# Embedding for token 285: torch.Size([])
# Embedding for token 286: torch.Size([])
# Embedding for token 287: torch.Size([])
# Embedding for token 288: torch.Size([])
# Embedding for token 289: torch.Size([])
# Embedding for token 290: torch.Size([])
# Embedding for token 291: torch.Size([])
# Embedding for token 292: torch.Size([])
# Embedding for token 293: torch.Size([])
# Embedding for token 294: torch.Size([])
# Embedding for token 295: torch.Size([])
# Embedding for token 296: torch.Size([])
# Embedding for token 297: torch.Size([])
# Embedding for token 298: torch.Size([])
# Embedding for token 299: torch.Size([])
# Embedding for token 300: torch.Size([])
# Embedding for token 301: torch.Size([])
# Embedding for token 302: torch.Size([])
# Embedding for token 303: torch.Size([])
# Embedding for token 304: torch.Size([])
# Embedding for token 305: torch.Size([])
# Embedding for token 306: torch.Size([])
# Embedding for token 307: torch.Size([])
# Embedding for token 308: torch.Size([])
# Embedding for token 309: torch.Size([])
# Embedding for token 310: torch.Size([])
# Embedding for token 311: torch.Size([])
# Embedding for token 312: torch.Size([])
# Embedding for token 313: torch.Size([])
# Embedding for token 314: torch.Size([])
# Embedding for token 315: torch.Size([])
# Embedding for token 316: torch.Size([])
# Embedding for token 317: torch.Size([])
# Embedding for token 318: torch.Size([])
# Embedding for token 319: torch.Size([])
# Embedding for token 320: torch.Size([])
# Embedding for token 321: torch.Size([])
# Embedding for token 322: torch.Size([])
# Embedding for token 323: torch.Size([])
# Embedding for token 324: torch.Size([])
# Embedding for token 325: torch.Size([])
# Embedding for token 326: torch.Size([])
# Embedding for token 327: torch.Size([])
# Embedding for token 328: torch.Size([])
# Embedding for token 329: torch.Size([])
# Embedding for token 330: torch.Size([])
# Embedding for token 331: torch.Size([])
# Embedding for token 332: torch.Size([])
# Embedding for token 333: torch.Size([])
# Embedding for token 334: torch.Size([])
# Embedding for token 335: torch.Size([])
# Embedding for token 336: torch.Size([])
# Embedding for token 337: torch.Size([])
# Embedding for token 338: torch.Size([])
# Embedding for token 339: torch.Size([])
# Embedding for token 340: torch.Size([])
# Embedding for token 341: torch.Size([])
# Embedding for token 342: torch.Size([])
# Embedding for token 343: torch.Size([])
# Embedding for token 344: torch.Size([])
# Embedding for token 345: torch.Size([])
# Embedding for token 346: torch.Size([])
# Embedding for token 347: torch.Size([])
# Embedding for token 348: torch.Size([])
# Embedding for token 349: torch.Size([])
# Embedding for token 350: torch.Size([])
# Embedding for token 351: torch.Size([])
# Embedding for token 352: torch.Size([])
# Embedding for token 353: torch.Size([])
# Embedding for token 354: torch.Size([])
# Embedding for token 355: torch.Size([])
# Embedding for token 356: torch.Size([])
# Embedding for token 357: torch.Size([])
# Embedding for token 358: torch.Size([])
# Embedding for token 359: torch.Size([])
# Embedding for token 360: torch.Size([])
# Embedding for token 361: torch.Size([])
# Embedding for token 362: torch.Size([])
# Embedding for token 363: torch.Size([])
# Embedding for token 364: torch.Size([])
# Embedding for token 365: torch.Size([])
# Embedding for token 366: torch.Size([])
# Embedding for token 367: torch.Size([])
# Embedding for token 368: torch.Size([])
# Embedding for token 369: torch.Size([])
# Embedding for token 370: torch.Size([])
# Embedding for token 371: torch.Size([])
# Embedding for token 372: torch.Size([])
# Embedding for token 373: torch.Size([])
# Embedding for token 374: torch.Size([])
# Embedding for token 375: torch.Size([])
# Embedding for token 376: torch.Size([])
# Embedding for token 377: torch.Size([])
# Embedding for token 378: torch.Size([])
# Embedding for token 379: torch.Size([])
# Embedding for token 380: torch.Size([])
# Embedding for token 381: torch.Size([])
# Embedding for token 382: torch.Size([])
# Embedding for token 383: torch.Size([])

# %% [markdown]
# **Text Embeddings (For Sentences and Whole Documents)**

# %%
from sentence_transformers import SentenceTransformer

# %%
# Load Model
model = SentenceTransformer('sentence-transformers/all-mpnet-base-v2')

# Convert text to text embeddings
vector = model.encode("Best movie ever!")

# %%
vector.shape
# Out:
# (768,)

# %% [markdown]
# **Word Embeddings Beyond LLMs**

# %%
# !pip install --upgrade transformers==4.41.2 sentence-transformers==3.0.1 gensim==4.3.2 scikit-learn==1.5.0 accelerate==0.31.0 peft==0.11.1 scipy==1.10.1 numpy==1.26.4
# Out:
# Collecting transformers==4.41.2
#   Using cached transformers-4.41.2-py3-none-any.whl.metadata (43 kB)
# Collecting sentence-transformers==3.0.1
#   Using cached sentence_transformers-3.0.1-py3-none-any.whl.metadata (10 kB)
# Collecting gensim==4.3.2
#   Using cached gensim-4.3.2.tar.gz (23.3 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting scikit-learn==1.5.0
#   Using cached scikit_learn-1.5.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting accelerate==0.31.0
#   Using cached accelerate-0.31.0-py3-none-any.whl.metadata (19 kB)
# Collecting peft==0.11.1
#   Using cached peft-0.11.1-py3-none-any.whl.metadata (13 kB)
# ERROR: Ignored the following yanked versions: 1.11.0, 1.14.0rc1
# ERROR: Ignored the following versions that require a different python version: 1.10.0 Requires-Python <3.12,>=3.8; 1.10.0rc1 Requires-Python <3.12,>=3.8; 1.10.0rc2 Requires-Python <3.12,>=3.8; 1.10.1 Requires-Python <3.12,>=3.8; 1.6.2 Requires-Python >=3.7,<3.10; 1.6.3 Requires-Python >=3.7,<3.10; 1.7.0 Requires-Python >=3.7,<3.10; 1.7.1 Requires-Python >=3.7,<3.10; 1.7.2 Requires-Python >=3.7,<3.11; 1.7.3 Requires-Python >=3.7,<3.11; 1.8.0 Requires-Python >=3.8,<3.11; 1.8.0rc1 Requires-Python >=3.8,<3.11; 1.8.0rc2 Requires-Python >=3.8,<3.11; 1.8.0rc3 Requires-Python >=3.8,<3.11; 1.8.0rc4 Requires-Python >=3.8,<3.11; 1.8.1 Requires-Python >=3.8,<3.11; 1.9.0 Requires-Python >=3.8,<3.12; 1.9.0rc1 Requires-Python >=3.8,<3.12; 1.9.0rc2 Requires-Python >=3.8,<3.12; 1.9.0rc3 Requires-Python >=3.8,<3.12; 1.9.1 Requires-Python >=3.8,<3.12
# ERROR: Could not find a version that satisfies the requirement scipy==1.10.1 (from versions: 0.8.0, 0.9.0, 0.10.0, 0.10.1, 0.11.0, 0.12.0, 0.12.1, 0.13.0, 0.13.1, 0.13.2, 0.13.3, 0.14.0, 0.14.1, 0.15.0, 0.15.1, 0.16.0, 0.16.1, 0.17.0, 0.17.1, 0.18.0, 0.18.1, 0.19.0, 0.19.1, 1.0.0, 1.0.1, 1.1.0, 1.2.0, 1.2.1, 1.2.2, 1.2.3, 1.3.0, 1.3.1, 1.3.2, 1.3.3, 1.4.0, 1.4.1, 1.5.0, 1.5.1, 1.5.2, 1.5.3, 1.5.4, 1.6.0, 1.6.1, 1.9.2, 1.9.3, 1.11.0rc1, 1.11.0rc2, 1.11.1, 1.11.2, 1.11.3, 1.11.4, 1.12.0rc1, 1.12.0rc2, 1.12.0, 1.13.0rc1, 1.13.0, 1.13.1, 1.14.0rc2, 1.14.0, 1.14.1, 1.15.0rc1, 1.15.0rc2, 1.15.0, 1.15.1, 1.15.2, 1.15.3, 1.16.0rc1, 1.16.0rc2, 1.16.0, 1.16.1, 1.16.2, 1.16.3, 1.17.0rc1)
# ERROR: No matching distribution found for scipy==1.10.1

# %%
# !pip install gensim sentence-transformers transformers scikit-learn accelerate peft
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.12/dist-packages (5.2.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.12.0)
# Requirement already satisfied: peft in /usr/local/lib/python3.12/dist-packages (0.18.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.5.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (2.9.0+cu126)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.2.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.0.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.11.12)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 72.4 MB/s eta 0:00:00
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0

# %%
import gensim.downloader as api

# %%
model = api.load("glove-wiki-gigaword-50")
# Out:
# [==================================================] 100.0% 66.0/66.0MB downloaded
